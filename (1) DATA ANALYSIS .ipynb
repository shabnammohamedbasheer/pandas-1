# %%
# !pip install pandas

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C813-D87B
#
#  Directory of C:\hello world\data analytics
#
# 19-07-2023  10:44    <DIR>          .
# 19-07-2023  10:44    <DIR>          ..
# 19-07-2023  10:43             4,869 (1) DATA ANALYSIS .ipynb
# 19-07-2023  10:31    <DIR>          .ipynb_checkpoints
# 18-02-2019  10:37               111 csv_mindex.csv
# 04-12-2021  15:33                59 demo1.csv
# 04-12-2021  19:05            10,545 demo1.xlsx
# 04-12-2021  15:36                43 demo2.csv
# 18-02-2019  10:37               169 demo3.csv
# 18-02-2019  10:37               170 demo3.txt
# 04-12-2021  16:35               169 demo4.csv
# 18-02-2019  10:37                78 demo5.csv
# 18-02-2019  10:37           626,863 demo6.csv
# 18-02-2019  10:37                36 demo7.csv
# 04-12-2021  16:49             6,189 demo_file.xlsx
# 18-02-2019  10:37           281,823 fdic_failed_bank_list.html
# 05-12-2021  18:17             2,681 final.csv
# ...

# %%
import pandas as pd

# %%
pd.read_csv("C:\hello world\data analytics\demo1.csv")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_csv("demo2.csv")
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12   file

# %%
pd.read_csv("demo3.csv")
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
import pandas as pd

# %%
pd.read_csv("test.tsv")
# Out:
#                        test\t test\ttest\ttest\ttest
# 0   Magnus\tMagnus\tMagnus\tMagnus\tMagnus\tMagnus\t
# 1  Carlsen\tCarlsen\tCarlsen\tCarlsen\tCarlsen\tC...

# %%
pd.read_csv("test.tsv",sep="\t")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pd.read_table("test.tsv")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pd.read_table("demo1.csv",sep=",")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_table("demo1.csv")
# Out:
#    a,b,c,d,message
# 0    1,2,3,4,hello
# 1    5,6,7,8,world
# 2  9,10,11,12,file

# %%
df=pd.read_table("test.tsv")
df
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C813-D87B
#
#  Directory of C:\hello world\data analytics
#
# 20-07-2023  18:56    <DIR>          .
# 20-07-2023  18:56    <DIR>          ..
# 20-07-2023  10:43            18,045 (1) DATA ANALYSIS .ipynb
# 20-07-2023  18:56    <DIR>          .ipynb_checkpoints
# 18-02-2019  10:37               111 csv_mindex.csv
# 20-07-2023  18:55           151,948 Data Analysis_Introduction_and_Implementation.ipynb
# 20-07-2023  08:37            35,322 Data Analysis_Introduction_and_Implementation@nisam.ipynb
# 04-12-2021  15:33                59 demo1.csv
# 04-12-2021  19:05            10,545 demo1.xlsx
# 04-12-2021  15:36                43 demo2.csv
# 18-02-2019  10:37               169 demo3.csv
# 18-02-2019  10:37               170 demo3.txt
# 04-12-2021  16:35               169 demo4.csv
# 18-02-2019  10:37                78 demo5.csv
# 18-02-2019  10:37           626,863 demo6.csv
# 18-02-2019  10:37                36 demo7.csv
# ...

# %%
import pandas as pd

# %%
pd.read_csv("demo1.csv")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_table("test.tsv")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pd.read_csv("test.tsv",sep="\t")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pd.read_csv("test.tsv")
# Out:
#                        test\t test\ttest\ttest\ttest
# 0   Magnus\tMagnus\tMagnus\tMagnus\tMagnus\tMagnus\t
# 1  Carlsen\tCarlsen\tCarlsen\tCarlsen\tCarlsen\tC...

# %%
pd.read_excel("demo1.xlsx")
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
pd.read_excel("demo1.xlsx",index_col=0)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
url="https://www.basketball-reference.com/players/c/collijo01.html"

# %%
pd.read_html(url)
# Out:
# [    Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
#  0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
#  1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
#  2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
#  3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
#  4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
#  5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
#  6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
#  1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
#  2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#  3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#  4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#  5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# ...

# %%
bask=pd.read_html(url)

# %%
bask
# Out:
# [    Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
#  0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
#  1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
#  2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
#  3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
#  4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
#  5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
#  6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
#  1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
#  2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#  3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#  4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#  5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# ...

# %%
bask_1=bask[0]

# %%
bask_1
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
bask_2=bask[-1]

# %%
bask_2
# Out:
#     Season   Age   Tm   Lg  Pos   G   MP   PER    TS%   3PAr  ...  \
# 0  2020-21  23.0  ATL  NBA   PF  18  576  15.3  0.632  0.308  ...
# 1  2021-22  24.0  ATL  NBA   PF   5  122  10.7  0.541  0.282  ...
# 2  2022-23  25.0  ATL  NBA   PF   6  164  10.1  0.543  0.533  ...
# 3   Career   NaN  NaN  NBA  NaN  29  862  13.7  0.601  0.352  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  0.9  0.8  1.7  0.140          NaN   1.1  -0.2  0.9   0.4
# 1          NaN  0.0  0.1  0.1  0.034          NaN  -0.8   0.0 -0.9   0.0
# 2          NaN  0.0  0.0  0.0 -0.007          NaN  -2.3  -1.1 -3.5  -0.1
# 3          NaN  0.8  0.9  1.7  0.097          NaN   0.2  -0.4 -0.2   0.4
#
# [4 rows x 29 columns]

# %%
bask_1.head()
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
# 3  2020-21  23.0  ATL  NBA  PF  63  63  29.3  6.8  12.2  ...  0.833  1.9  5.5
# 4  2021-22  24.0  ATL  NBA  PF  54  53  30.8  6.3  11.9  ...  0.793  1.7  6.1
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#
# [5 rows x 30 columns]

# %%
bask_1.head(3)
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#
# [3 rows x 30 columns]

# %%
bask_1.head(4)
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
# 3  2020-21  23.0  ATL  NBA  PF  63  63  29.3  6.8  12.2  ...  0.833  1.9  5.5
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#
# [4 rows x 30 columns]

# %%
bask_1.head(10)
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
bask_1.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
bask_1.shape
# Out:
# (7, 30)

# %%
import pandas as pd

# %%
data_git = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data_git
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_git.shape
# Out:
# (891, 12)

# %%
data_git.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_git.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data_ht = pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
data_ht

# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C813-D87B
#
#  Directory of C:\hello world\data analytics
#
# 21-07-2023  18:45    <DIR>          .
# 21-07-2023  18:45    <DIR>          ..
# 21-07-2023  11:12           114,578 (1) DATA ANALYSIS .ipynb
# 20-07-2023  18:56    <DIR>          .ipynb_checkpoints
# 18-02-2019  10:37               111 csv_mindex.csv
# 21-07-2023  18:44           237,273 Data Analysis_Introduction_and_Implementation.ipynb
# 04-12-2021  15:33                59 demo1.csv
# 04-12-2021  19:05            10,545 demo1.xlsx
# 04-12-2021  15:36                43 demo2.csv
# 18-02-2019  10:37               169 demo3.csv
# 18-02-2019  10:37               170 demo3.txt
# 04-12-2021  16:35               169 demo4.csv
# 18-02-2019  10:37                78 demo5.csv
# 18-02-2019  10:37           626,863 demo6.csv
# 18-02-2019  10:37                36 demo7.csv
# 04-12-2021  16:49             6,189 demo_file.xlsx
# ...

# %%
pd.read_csv("survey_results_public.csv")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.read_table("survey_results_public.csv",sep=",")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.read_table("test.tsv")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
pd.read_csv("test.tsv",sep="\t")
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
data2=pd.read_table("demo2.csv",sep=",")
data2
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12   file

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data2.loc[0]
# Out:
# 1            5
# 2            6
# 3            7
# 4            8
# hello    world
# Name: 0, dtype: object

# %%
df = pd.read_csv('demo6.csv',usecols=["one","three"])
df
# Out:
#            one     three
# 0     0.467976 -0.295344
# 1    -0.358893  0.704965
# 2    -0.501840 -0.421691
# 3     0.204886  1.388361
# 4     0.354628  0.283763
# ...        ...       ...
# 9995  2.311896 -1.409599
# 9996 -0.479893  0.745152
# 9997  0.523331  0.486066
# 9998 -0.362559 -1.843201
# 9999 -0.096376 -0.657431
#
# [10000 rows x 2 columns]

# %%
pd.read_csv("demo6.csv")
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv("demo6.csv",usecols=["one","three"])
# Out:
#            one     three
# 0     0.467976 -0.295344
# 1    -0.358893  0.704965
# 2    -0.501840 -0.421691
# 3     0.204886  1.388361
# 4     0.354628  0.283763
# ...        ...       ...
# 9995  2.311896 -1.409599
# 9996 -0.479893  0.745152
# 9997  0.523331  0.486066
# 9998 -0.362559 -1.843201
# 9999 -0.096376 -0.657431
#
# [10000 rows x 2 columns]

# %%
pd.read_csv("demo4.csv")
# Out:
#                                                                  # hey!
# a                                                  b   c   d    message
# # just wanted to make things more understandable   NaN NaN NaN      NaN
# # do you have enough skills to become a data sc... NaN NaN NaN      NaN
# 1                                                  2   3   4      hello
# 5                                                  6   7   8      world
# 9                                                  10  11  12       foo

# %%
pd.read_csv("demo4.csv",skiprows=[0,1,3])
# Out:
#            # just wanted to make things more understandable
# 1 2  3  4                                             hello
# 5 6  7  8                                             world
# 9 10 11 12                                              foo

# %%
df1 = pd.read_csv("demo1.csv",names=['one',"two","three","four","five"])
df1
# Out:
#   one two three four     five
# 0   a   b     c    d  message
# 1   1   2     3    4    hello
# 2   5   6     7    8    world
# 3   9  10    11   12     file

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C813-D87B
#
#  Directory of C:\hello world\data analytics
#
# 21-07-2023  20:05    <DIR>          .
# 21-07-2023  20:05    <DIR>          ..
# 21-07-2023  20:05           186,239 (1) DATA ANALYSIS .ipynb
# 20-07-2023  18:56    <DIR>          .ipynb_checkpoints
# 18-02-2019  10:37               111 csv_mindex.csv
# 21-07-2023  18:44           237,273 Data Analysis_Introduction_and_Implementation.ipynb
# 04-12-2021  15:33                59 demo1.csv
# 04-12-2021  19:05            10,545 demo1.xlsx
# 04-12-2021  15:36                43 demo2.csv
# 18-02-2019  10:37               169 demo3.csv
# 18-02-2019  10:37               170 demo3.txt
# 04-12-2021  16:35               169 demo4.csv
# 18-02-2019  10:37                78 demo5.csv
# 18-02-2019  10:37           626,863 demo6.csv
# 18-02-2019  10:37                36 demo7.csv
# 04-12-2021  16:49             6,189 demo_file.xlsx
# ...

# %%
pd.read_excel("demo_file.xlsx")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel("demo_file.xlsx")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel("Desktop/Rent Details New as on 13.07.2023.xlsx"
# Out:
#   Cell In[26], line 1
#     pd.read_excel("Desktop/Rent Details New as on 13.07.2023.xlsx"
#                                                                   ^
# SyntaxError: incomplete input

# %%
pd.read_excel("demo1.xlsx")
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
pd.read_excel("demo1.xlsx",index_col=[0])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import pandas as pd

# %%
url="https://www.basketball-reference.com/players/c/collijo01.html"

# %%
bask=pd.read_html(url)

# %%
bask[0]
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
bask[1]
# Out:
#     Season   Age   Tm   Lg  Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2020-21  23.0  ATL  NBA   PF  18  18  32.0  5.6  10.1  ...  0.833  2.0
# 1  2021-22  24.0  ATL  NBA   PF   5   4  24.4  3.8   7.8  ...  0.500  0.4
# 2  2022-23  25.0  ATL  NBA   PF   6   6  27.3  4.3  10.0  ...  0.833  1.2
# 3   Career   NaN  NaN  NBA  NaN  29  28  29.7  5.0   9.7  ...  0.769  1.6
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  6.7  8.7  0.9  0.4  0.6  1.3  3.3  13.9
# 1  4.2  4.6  1.2  0.4  0.2  1.0  2.4   9.4
# 2  3.2  4.3  0.8  0.3  1.0  1.5  2.2  11.3
# 3  5.6  7.1  0.9  0.4  0.6  1.3  2.9  12.6
#
# [4 rows x 30 columns]

# %%
bask1=bask[2]

# %%
bask1.head
# Out:
# <bound method NDFrame.head of                  Highlight  Unnamed: 1                        In Stathead
# 0      Career high, Points        38.0  View full stats from top 20 games
# 1    Career high, Rebounds        25.0  View full stats from top 20 games
# 2     Career high, Assists         6.0  View full stats from top 20 games
# 3      Career high, Steals         4.0  View full stats from top 20 games
# 4      Career high, Blocks         5.0  View full stats from top 20 games
# 5  Career high, Game Score        35.9  View full stats from top 20 games>

# %%
bask1.head(2)
# Out:
#                Highlight  Unnamed: 1                        In Stathead
# 0    Career high, Points        38.0  View full stats from top 20 games
# 1  Career high, Rebounds        25.0  View full stats from top 20 games

# %%
bask1.columns
# Out:
# Index(['Highlight', 'Unnamed: 1', 'In Stathead'], dtype='object')

# %%
bask1.shape
# Out:
# (6, 3)

# %%
data_git=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\hello world\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 data_git=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
#
# ...

# %%
data_iris  =pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data_git
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 data_git
#
# NameError: name 'data_git' is not defined

# %%
pd.read_html("file:///C:/Users/codem/Downloads/404.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\hello world\lib\urllib\request.py:1505, in FileHandler.open_local_file(self, req)
#    1504 try:
# -> 1505     stats = os.stat(localfile)
#    1506     size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\codem\\Downloads\\404.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 pd.read_html("file:///C:/Users/codem/Downloads/404.html")
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
titanic=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\hello world\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\hello world\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\hello world\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
titanic

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
writable_file=titanic[["Survived","Name","Embarked"]]

# %%
writable_file
# Out:
#      Survived                                               Name Embarked
# 0           0                            Braund, Mr. Owen Harris        S
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...        C
# 2           1                             Heikkinen, Miss. Laina        S
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)        S
# 4           0                           Allen, Mr. William Henry        S
# ..        ...                                                ...      ...
# 886         0                              Montvila, Rev. Juozas        S
# 887         1                       Graham, Miss. Margaret Edith        S
# 888         0           Johnston, Miss. Catherine Helen "Carrie"        S
# 889         1                              Behr, Mr. Karl Howell        C
# 890         0                                Dooley, Mr. Patrick        Q
#
# [891 rows x 3 columns]

# %%
writable_file.to_csv("newtitanic.csv")

# %%
writable_file.to_excel("newtitanicexcel.xlsx")

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.shape[0]
# Out:
# 891

# %%
titanic.shape[1]
# Out:
# 12

# %%
embark_name=titanic[["Name","Embarked"]]

# %%
embark_name
# Out:
#                                                   Name Embarked
# 0                              Braund, Mr. Owen Harris        S
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...        C
# 2                               Heikkinen, Miss. Laina        S
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)        S
# 4                             Allen, Mr. William Henry        S
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas        S
# 887                       Graham, Miss. Margaret Edith        S
# 888           Johnston, Miss. Catherine Helen "Carrie"        S
# 889                              Behr, Mr. Karl Howell        C
# 890                                Dooley, Mr. Patrick        Q
#
# [891 rows x 2 columns]

# %%
embark_name.to_csv("C:\hello world\data analytics\embarked.csv")

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C813-D87B
#
#  Directory of C:\hello world\data analytics
#
# 25-07-2023  08:42    <DIR>          .
# 25-07-2023  08:42    <DIR>          ..
# 25-07-2023  08:42           397,727 (1) DATA ANALYSIS .ipynb
# 23-07-2023  21:26    <DIR>          .ipynb_checkpoints
# 24-07-2023  09:24            95,819 ASSIGNMENT.ipynb
# 18-02-2019  10:37               111 csv_mindex.csv
# 24-07-2023  09:37           234,062 Data Analysis_Introduction_and_Implementation.ipynb
# 04-12-2021  15:33                59 demo1.csv
# 04-12-2021  19:05            10,545 demo1.xlsx
# 24-07-2023  07:16                87 demo1_new.csv
# 04-12-2021  15:36                43 demo2.csv
# 18-02-2019  10:37               169 demo3.csv
# 18-02-2019  10:37               170 demo3.txt
# 04-12-2021  16:35               169 demo4.csv
# 18-02-2019  10:37                78 demo5.csv
# 18-02-2019  10:37           626,863 demo6.csv
# ...

# %%
embark_name.to_excel("data analytics\embarked1.xlsx")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 embark_name.to_excel("data analytics\embarked1.xlsx")
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
data3=pd.read_csv("demo5.csv")

# %%
data3
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data3.to_csv("file.csv","@")

# %%
titanic[["Name","Survived","Age"]].to_csv("withoutindex.csv",index=False,header=False)

# %%
titanic[["Name","Survived","Age"]].to_csv("withoutindex1.csv")

# %%
html=pd.read_html("fdic_failed_bank_list.html")

# %%
html
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
html[0]
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
data2=html[0]

# %%
data2[["Bank Name","City"]].to_pickle("newhtml.pkl")

# %%
data3=pd.read_pickle("newhtml.pkl")

# %%
data3
# Out:
#                              Bank Name             City
# 0                          Allied Bank         Mulberry
# 1         The Woodbury Banking Company         Woodbury
# 2               First CornerStone Bank  King of Prussia
# 3                   Trust Company Bank          Memphis
# 4           North Milwaukee State Bank        Milwaukee
# ..                                 ...              ...
# 542                 Superior Bank, FSB         Hinsdale
# 543                Malta National Bank            Malta
# 544    First Alliance Bank & Trust Co.       Manchester
# 545  National State Bank of Metropolis       Metropolis
# 546                   Bank of Honolulu         Honolulu
#
# [547 rows x 2 columns]

# %%
data2
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
data2.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
data2.tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 542                 Superior Bank, FSB    Hinsdale  IL  32646
# 543                Malta National Bank       Malta  OH   6629
# 544    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 545  National State Bank of Metropolis  Metropolis  IL   3815
# 546                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date       Updated Date
# 542                Superior Federal, FSB      July 27, 2001    August 19, 2014
# 543                    North Valley Bank        May 3, 2001  November 18, 2002
# 544  Southern New Hampshire Bank & Trust   February 2, 2001  February 18, 2003
# 545              Banterra Bank of Marion  December 14, 2000     March 17, 2005
# 546                   Bank of the Orient   October 13, 2000     March 17, 2005

# %%
data2.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
data2["City"].unique()
# Out:
# array(['Mulberry', 'Woodbury', 'King of Prussia', 'Memphis', 'Milwaukee',
#        'Longview', 'Peachtree City', 'Denver', 'Chicago', 'San Juan',
#        'Atlanta', 'Crestview', 'Mankato', 'Palm Desert', 'Rising Sun',
#        'Conyers', 'Freedom', 'Fort Lauderdale', 'Moline', 'Bel Air',
#        'Cincinnati', 'Berwyn', 'Fairfax', 'Horsham', 'Sterling', 'Boise',
#        'El Reno', 'West Chicago', 'The Woodlands', 'Graceville',
#        'Edinburg', 'Bridgeport', 'Phoenix', 'Parsons', 'Wausau',
#        'Fort Myers', 'Sevierville', 'North Las Vegas', 'Kenosha',
#        'Scottsdale', 'Valdosta', 'Asheville', 'Douglasville', 'Lenoir',
#        'Marianna', 'Orange Park', 'Lexington', 'Gold Canyon', 'LaGrange',
#        'Andover', 'University Place', 'Sunrise Beach', 'Braselton',
#        'Princeton', 'Lutz', 'Sedalia', 'Tamarac', 'Destin', 'Crete',
#        'St. Louis', 'Bloomington', 'Waukegan', 'Jasper', 'Leawood',
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
 titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.select_dtypes(["int64","float64"])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
import pandas as pd

# %%
pd.read_csv("csv_mindex.csv")
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
url="https://www.basketball-reference.com/players/c/collijo01.html"
bask=pd.read_html(url)

# %%
bask
# Out:
# [    Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
#  0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
#  1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
#  2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
#  3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
#  4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
#  5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
#  6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
#  1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
#  2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#  3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#  4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#  5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# ...

# %%
bask.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bask.head(10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
bask1=bask[0]

# %%
bask1
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
bask1.head()
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
# 3  2020-21  23.0  ATL  NBA  PF  63  63  29.3  6.8  12.2  ...  0.833  1.9  5.5
# 4  2021-22  24.0  ATL  NBA  PF  54  53  30.8  6.3  11.9  ...  0.793  1.7  6.1
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#
# [5 rows x 30 columns]

# %%
bask1.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
bask1.shape
# Out:
# (7, 30)

# %%
bask1.size
# Out:
# 210

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
writable_file=titanic[["Survived","Name","Age"]]

# %%
writable_file
# Out:
#      Survived                                               Name   Age
# 0           0                            Braund, Mr. Owen Harris  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2           1                             Heikkinen, Miss. Laina  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4           0                           Allen, Mr. William Henry  35.0
# ..        ...                                                ...   ...
# 886         0                              Montvila, Rev. Juozas  27.0
# 887         1                       Graham, Miss. Margaret Edith  19.0
# 888         0           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889         1                              Behr, Mr. Karl Howell  26.0
# 890         0                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 3 columns]
